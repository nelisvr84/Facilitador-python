# %% [markdown]
# <a href="https://colab.research.google.com/github/nelisvr84/Facilitador-python/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded =  files.upload()
import pandas as pd

df =  pd.read_csv("df_exemplo_m2w1 (2).csv", sep="\s")
# Out:
#      <input type="file" id="files-405d96b4-cb8f-42c1-8d4e-e73793983b16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-405d96b4-cb8f-42c1-8d4e-e73793983b16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#       Sta_ID                                Depth_ID  Depthm  T_degC  O2Sat  \
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0000B-3       0   10.30   92.8
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0006A-3       6   18.46  111.8
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0010A-7      10   10.29   95.0
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0015A-3      15   10.29   95.3
# 44.0    48.5  19-4904CR-HY-087-0606-04400485-0020A-7      20   10.33   95.1
# ...      ...                                     ...     ...     ...    ...
# 36.7   115.0  19-4911BD-HY-318-2130-03671150-0921A-3     921    3.91    4.8
# 36.7   115.0  19-4911BD-HY-318-2130-03671150-1000A-7    1000    3.73    5.4
# 36.7   115.0  19-4911BD-HY-318-2130-03671150-1100A-7    1100    3.51    6.4
# 36.7   115.0  19-4911BD-HY-318-2130-03671150-1200A-7    1200    3.29    7.3
# 36.7   115.0  19-4911BD-HY-318-2130-03671150-1247A-3    1247    3.18    7.6
#
#       Salnty
# 44.0  33.030
# 44.0  32.920
# ...

# %%
from google.colab import files
uploaded =  files.upload()
import pandas as pd
df =  pd.read_csv("df_exemplo_m2w1 (2).csv", sep="\s")
df
df['Salnty']
# Out:
#      <input type="file" id="files-1c318c8f-d350-48b1-b048-c986644d14bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c318c8f-d350-48b1-b048-c986644d14bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded =  files.upload()
import pandas as pd
df =  pd.read_csv("df_exemplo_m2w1 (2).csv", sep="\s")
df
df['Salnty']
# Out:
#      <input type="file" id="files-1c1a76e3-11df-40d2-8110-40b2ceb0ae57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c1a76e3-11df-40d2-8110-40b2ceb0ae57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded =  files.upload()
import pandas as pd
df =  pd.read_csv("df_exemplo_m2w1 (2).csv", sep="\s")
df
df['Salnty']
df['Salnty'].describe()
# Out:
#      <input type="file" id="files-a56ae3e8-ad29-4c7e-a8a0-60e681f27777" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a56ae3e8-ad29-4c7e-a8a0-60e681f27777">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
 from google.colab import files
uploaded =  files.upload()
import pandas as pd
df =  pd.read_csv("df_exemplo_m2w1 (2).csv", sep="\s")
df
df['Salnty']
df['Salnty'].round().mode()
# Out:
#      <input type="file" id="files-8c246093-f99c-4c70-a86b-21850737654e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c246093-f99c-4c70-a86b-21850737654e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded =  files.upload()
import pandas as pd
df =  pd.read_csv("df_exemplo_m2w1 (2).csv", sep="\s")
df
df['Salnty']
df['Salnty'].median()
# Out:
#      <input type="file" id="files-6c7804c3-edbd-4f9b-ac3e-25e24fa6735a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c7804c3-edbd-4f9b-ac3e-25e24fa6735a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
